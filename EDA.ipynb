# %%
# !pip install numpy

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1=pd.read_csv(r'D:\Yogesh Data\Product.csv')

# %%
df1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  New
# 0                 NaN                 NaN      8370  NaN
# 1                 6.0                14.0     15200  NaN
# ...

# %%
df2=pd.read_csv(r'D:\Yogesh Data\Customer_Sales_Data.csv')

# %%
df2.head()
# Out:
#    InvoiceLineID                                        Description  \
# 0         221910  Black and orange glass with care despatch tape...
# 1         221910  Black and orange glass with care despatch tape...
# 2         221915  Black and orange glass with care despatch tape...
# 3         221916              Shipping carton (Brown) 305x305x305mm
# 4         222076  RC toy sedan car with remote control (Red) 1/5...
#
#                     CustomerName                 CityState  Sales
# 0      Wingtip Toys (Delray, WV)   Delray (Andhra Pradesh)   2000
# 1      Wingtip Toys (Delray, WV)    Delray (Uttar Pradesh)  10100
# 2      Wingtip Toys (Delray, WV)    Delray (West Virginia)    101
# 3                  Kumar Naicker  Oconto Falls (Wisconsin)    105
# 4  Tailspin Toys (Sylvanite, MT)       Sylvanite (Montana)     15

# %%
df1.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase  New
# 550063                 NaN                 NaN       368  NaN
# ...

# %%
df2.tail()
# Out:
#       InvoiceLineID                                        Description  \
# 4296         228261  RC toy sedan car with remote control (Red) 1/5...
# 4297         228262                         USB rocket launcher (Gray)
# 4298         228263                    Alien officer hoodie (Black) XL
# 4299         228264           20 mm Anti static bubble wrap (Blue) 50m
# 4300         228265     Furry gorilla with big eyes slippers (Black) S
#
#                         CustomerName                   CityState  Sales
# 4296  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)     23
# 4297  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)      4
# 4298  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)     47
# 4299  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)    612
# 4300  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)     38

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4301 entries, 0 to 4300
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   InvoiceLineID  4301 non-null   int64
#  1   Description    4301 non-null   object
#  2   CustomerName   4301 non-null   object
#  3   CityState      4301 non-null   object
#  4   Sales          4301 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 168.1+ KB

# %%
df2.describe()
# Out:
#        InvoiceLineID         Sales
# count    4301.000000   4301.000000
# mean   225052.253662    116.614973
# std      1817.016724    275.883226
# min    221910.000000      1.000000
# 25%    223484.000000     14.000000
# 50%    225072.000000     38.000000
# 75%    226616.000000    130.000000
# max    228265.000000  10100.000000

# %%
df1.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase  New
# count       376430.000000       166821.000000  550068.000000  0.0
# mean             9.842329           12.668243    9263.968713  NaN
# std              5.086590            4.125338    5023.065394  NaN
# ...

# %%
df1.shape
# Out:
# (550068, 13)

# %%
df2.shape
# Out:
# (4301, 5)

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      --------------------- ----------------- 92.2/165.9 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------  163.8/165.9 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 1.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB 9.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.8/8.0 MB 10.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.8/8.0 MB 10.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/8.0 MB 5.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.0 MB 5.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.0 MB 5.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.0 MB 5.6 MB/s eta 0:00:02
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df2.tail()
# Out:
#       InvoiceLineID                                        Description  \
# 4296         228261  RC toy sedan car with remote control (Red) 1/5...
# 4297         228262                         USB rocket launcher (Gray)
# 4298         228263                    Alien officer hoodie (Black) XL
# 4299         228264           20 mm Anti static bubble wrap (Blue) 50m
# 4300         228265     Furry gorilla with big eyes slippers (Black) S
#
#                         CustomerName                   CityState  Sales
# 4296  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)     23
# 4297  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)      4
# 4298  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)     47
# 4299  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)    612
# 4300  Wingtip Toys (Penns Creek, PA)  Penns Creek (Pennsylvania)     38
